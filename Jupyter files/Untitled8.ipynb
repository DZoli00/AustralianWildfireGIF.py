# %%
table = pd.read_csv("CleanedDataV4.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
table
# Out:
#        Unnamed: 0  latitude  longitude    acq_date  acq_time  confidence  \
# 0             286  -14.0453   131.4964  2019-08-01       524          66
# 1             300  -14.6748   126.7174  2019-08-01       524          54
# 2             319  -11.4433   130.4870  2019-08-01       525          92
# 3             370  -14.8038   144.3157  2019-08-01      1311          75
# 4              64  -16.1501   136.6857  2019-08-01        58          92
# ...           ...       ...        ...         ...       ...         ...
# 27603       35619  -15.9764   144.6063  2019-09-30       410          59
# 27604       35569  -22.4522   150.7220  2019-09-30       408          65
# 27605       35736  -12.0852   141.8547  2019-09-30       411         100
# 27606       35895  -16.4940   124.2070  2019-09-30       548          81
# 27607       35398  -13.3222   132.3516  2019-09-30       122          85
#
#        fire_temperature
# 0                 51.05
# 1                 55.75
# ...

# %%
table.confidence
# Out:
# 0         66
# 1         54
# 2         92
# 3         75
# 4         92
#         ...
# 27603     59
# 27604     65
# 27605    100
# 27606     81
# 27607     85
# Name: confidence, Length: 27608, dtype: int64

# %%
table.acq_date
# Out:
# 0        2019-08-01
# 1        2019-08-01
# 2        2019-08-01
# 3        2019-08-01
# 4        2019-08-01
#             ...
# 27603    2019-09-30
# 27604    2019-09-30
# 27605    2019-09-30
# 27606    2019-09-30
# 27607    2019-09-30
# Name: acq_date, Length: 27608, dtype: object

# %%
table.acq_date[0]
# Out:
# '2019-08-01'

# %%
if table.acq_date[0]=='2019-08-01':
    print(9)
# Out:
# 9

# %%
data=table['acq_date']
data_array=data.values
data_array
# Out:
# array(['2019-08-01', '2019-08-01', '2019-08-01', ..., '2019-09-30',
#        '2019-09-30', '2019-09-30'], dtype=object)

# %%
table=table.loc[table['acq_date'] == '2019-08-01']
values10 = table.confidence
plt.plot(values10)
plt.title("1.08.2019")
plt.show()

# %%
table=table.loc[table['acq_date'] == '2019-08-15']
values10 = table.confidence
plt.plot(values10)
plt.title("15.08.2019")
plt.show()

# %%
table=table.loc[table['acq_date'] == '2019-08-29']
values10 = table.confidence
plt.plot(values10)
plt.title("29.08.2019")
plt.show()

# %%
table=table.loc[table['acq_date'] == '2019-09-14']
values10 = table.confidence
plt.plot(values10)
plt.title("14.09.2019")
plt.show()

# %%
table=table.loc[table['acq_date'] == '2019-09-30']
values10 = table.confidence
plt.plot(values10)
plt.title("30.09.2019")
plt.show()

# %%
values20 = table.confidence[12262::]
plt.plot(values20)
plt.title("1-30.09.2019")
plt.show()

# %%
values10 = table.confidence[::12261]
plt.plot(values10)
plt.title("1-31.08.2019")
plt.show()

# %%
values1 = table.confidence[2::2666]
plt.plot(values1)
plt.title("1-7.08.2019")
plt.show()
values2 = table.confidence[2667::6241]
plt.plot(values2)
plt.title("8-14.08.2019")
plt.show()
values3 = table.confidence[6242::8848]
plt.plot(values3)
plt.title("15-21.08.2019")
plt.show()
values4 = table.confidence[8849::11208]
plt.plot(values4)
plt.title("22-28.08.2019")
plt.show()
values5 = table.confidence[11209::12260]
plt.plot(values5)
plt.title("29-31.08.2019")
plt.show()

plt.plot(values1)
plt.plot(values2)
plt.plot(values3)
plt.plot(values4)
plt.plot(values5)
plt.legend(['1-7.08.2019', '8-14.08.2019', '15-21.08.2019', '22-28.08.2019', '29-31.08.2019'], loc=4, ncol=1)
plt.title("August 2019")
plt.show()
# Out:
#   File "<ipython-input-231-f7e09300dcd3>", line 31
#     'plt.plot(values1)
#                       ^
# SyntaxError: EOL while scanning string literal

# %%
values6 = table.confidence[12261::16075]
plt.plot(values1)
plt.title("1-7.09.2019")
plt.show()
values7 = table.confidence[16076::21847]
plt.plot(values2)
plt.title("8-14.09.2019")
plt.show()
values8 = table.confidence[21848::24529]
plt.plot(values3)
plt.title("15-21.09.2019")
plt.show()
values9 = table.confidence[24530::26626]
plt.plot(values4)
plt.title("22-28.09.2019")
plt.show()
values10 = table.confidence[26627::27609]
plt.plot(values5)
plt.title("29-31.09.2019")
plt.show()

plt.plot(values6)
plt.plot(values7)
plt.plot(values8)
plt.plot(values9)
plt.plot(values10)
plt.legend(['1-7.09.2019', '8-14.09.2019', '15-21.09.2019', '22-28.09.2019', '29-30.09.2019'], loc=4, ncol=1)
plt.title("Septembrie 2019")
plt.show()

# %%
data = table['acq_date']
data_array = data.values
data_array
# Out:
# array(['2019-08-01', '2019-08-01', '2019-08-01', ..., '2019-09-30',
#        '2019-09-30', '2019-09-30'], dtype=object)

# %%
table.acq_date
# Out:
# 0        2019-08-01
# 1        2019-08-01
# 2        2019-08-01
# 3        2019-08-01
# 4        2019-08-01
#             ...
# 27603    2019-09-30
# 27604    2019-09-30
# 27605    2019-09-30
# 27606    2019-09-30
# 27607    2019-09-30
# Name: acq_date, Length: 27608, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
df = pd.Series()
# Out:
# C:\Users\madalina\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
